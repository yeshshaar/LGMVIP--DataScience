# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
fish_image = cv2.imread("fish.jpg")
cv2_imshow(fish_image)
# Out:
# <PIL.Image.Image image mode=RGB size=534x360 at 0x7FBB2C660950>

# %%
rbg = cv2.cvtColor(fish_image, cv2.COLOR_BGR2RGB)
cv2_imshow(rbg)
# Out:
# <PIL.Image.Image image mode=RGB size=534x360 at 0x7FBB2C5FE750>

# %%
gray_scale = cv2.cvtColor(rbg, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_scale)
# Out:
# <PIL.Image.Image image mode=L size=534x360 at 0x7FBB2C60AFD0>

# %%
inverted_gray_scale = 255 - gray_scale
cv2_imshow(inverted_gray_scale )
# Out:
# <PIL.Image.Image image mode=L size=534x360 at 0x7FBB2C60A910>

# %%
blur_image = cv2.GaussianBlur(inverted_gray_scale, (21,21), 0)
cv2_imshow(blur_image)
# Out:
# <PIL.Image.Image image mode=L size=534x360 at 0x7FBB2C615D10>

# %%
inverted_blur = 255 - blur_image
cv2_imshow(inverted_blur)
# Out:
# <PIL.Image.Image image mode=L size=534x360 at 0x7FBB2C5FE590>

# %%
pencil_sketch = cv2.divide(gray_scale, inverted_blur, scale=255)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=534x360 at 0x7FBB2B59B610>
